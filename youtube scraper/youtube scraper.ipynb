# %%
from selenium import webdriver
import cromedriver_binary
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 from selenium import webdriver
# ----> 2 import cromedriver_binary
#
# ModuleNotFoundError: No module named 'cromedriver_binary'
